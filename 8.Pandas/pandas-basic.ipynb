# %%
import pandas as pd   # pd yha pr alis h , taki baar baar hme pandas na likhna padhe uske jgh pd likh de

# %%
df = pd.read_csv("services.csv") # pandas ke thorough ham csv file ke data ko read kar rhe h
                  # csv means comma separated values
                  # data ko ham df nam ke object ke andr store kr rhe h

# %%
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# always remember pandas hmesa structured data hi read karta h

# unstructure data ko pandas read nhi karta h

# %%
# structured_data means tubular form of data , jaise jo data ham excel sheet me rkhte h

# %%
df.head()  # head hme first five data de deta h
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
# pandas jab v data read karta h to vo by default manta h ki ,
  # phla vala jo row h ,vo column ka name h

''' 
agar hmare data me column name nhi available h to header ke parameter me ja kar ham usko none kar dete h
'''

# %%
df.head(3) # agr hme sirf 3 record hi dekhna h, to parameter me 3 de denge
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
#
#                                          description  \
# 0  A walk-in center for older adults that provide...
# 1  Provides training and job placement to eligibl...
# 2  Offers supportive counseling services to San M...
#
#                                          eligibility email  ...  \
# ...

# %%
# by default pandas row ki indexing kar deta h , 0,1,2 ,, upr vale me dekh skte h ham.

# %%
df.tail() # last five record hame dikhata h .tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
# tail ke andr ham parameter de kar required amount ke data ko pa skte h

df.tail(3) # last ke tin data ko dikha rha h
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...         NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# data frame means tubular form of data

# sql based data and datastructure based operations ko ham pandas ke andr kar skte h

# %%
df.columns # columns ke name ko hme la kar de dega
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='object')

# %%
list(df.columns) # agr list me data hme chahiye
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
df['service_areas'] # selected column ke data ko ham pa skte h , iss trh se
# Out:
# 0                                     Colma
# 1                          San Mateo County
# 2                          San Mateo County
# 3                          San Mateo County
# 4                          San Mateo County
# 5                          San Mateo County
# 6       Belmont, Burlingame, East Palo Alto
# 7                   Belmont, East Palo Alto
# 8                          San Mateo County
# 9                          San Mateo County
# 10                         San Mateo County
# 11                                Daly City
# 12                         San Mateo County
# 13      Belmont, Burlingame, East Palo Alto
# 14         Alameda County, San Mateo County
# 15                                      NaN
# 16    Colma, Daly City, South San Francisco
# 17                           East Palo Alto
# 18                      Belmont, Burlingame
# 19                                      NaN
# 20                         San Mateo County
# ...

# %%
df['website']
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21    http://www.example.com
# 22    http://www.example.com
# Name: website, dtype: object

# %%
type(df['website'])
# Out:
# pandas.core.series.Series

# %%
# series is equivalent to list , pandas me jo dataframes h , ussse agar ham single data ko nikalte
# to vo data series me deta h , ultimalely series is equivalent to list.

# %%
list(df['status'])
# Out:
# ['active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'active',
#  'defunct',
#  'inactive',
#  'active',
#  'active']

# %%
# series ar list ke andr difference itna h ki , series hame indexing v dikhata h 
# lekin list hme indexing nhi dikhata h

# %% [markdown]
# #### series image
#
# ![Screenshot 2023-12-27 140013](https://github.com/anu78600/Learning/assets/123054203/42cfcf3a-8df9-4962-8f6e-53010fca246a)
#
# #### list image
#
# ![Screenshot 2023-12-27 140221](https://github.com/anu78600/Learning/assets/123054203/eaf98941-5aa5-402b-b481-370a3f8ebb98)

# %%
df[['status']]
# Out:
#       status
# 0     active
# 1     active
# 2     active
# 3     active
# 4     active
# 5     active
# 6     active
# 7     active
# 8     active
# 9     active
# 10    active
# 11    active
# 12    active
# 13    active
# 14    active
# 15    active
# 16    active
# 17    active
# 18    active
# 19   defunct
# 20  inactive
# 21    active
# 22    active

# %%
type(df[['status']])
# Out:
# pandas.core.frame.DataFrame

# %%
# agr ham bina list ke pass karte h yek column ka nam to vo series return karta h
# agr list ke andr pass kiya to vo bann jata h dataframe

# %%
df['email','keywords']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\anupa\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('email', 'keywords')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ...

# %%
'''multiple column ke case me hme as a list column ko pass karna hota h , otherwise vo error de deta h  '''
# Out:
# 'multiple column ke case me hme as a list column ko pass karna hota h , otherwise vo error de deta h  '

# %%
df[['email','keywords']] # inside list ham multiple column pass kar ke data ko pa skte h
# Out:
#                     email                                           keywords
# 0                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 1                     NaN  EMPLOYMENT/TRAINING SERVICES, Job Development,...
# 2                     NaN  Geriatric Counseling, Older Adults, Gay, Lesbi...
# 3                     NaN  INDIVIDUAL AND FAMILY DEVELOPMENT SERVICES, Gr...
# 4                     NaN     COMMUNITY SERVICES, Speakers, Automobile Loans
# 5                     NaN  ADULT PROTECTION AND CARE SERVICES, In-Home Su...
# 6                     NaN  ADULT PROTECTION AND CARE SERVICES, Adult Day ...
# 7                     NaN  ADULT PROTECTION AND CARE SERVICES, Meal Sites...
# 8                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 9                     NaN  EDUCATION SERVICES, Library, Libraries, Public...
# 10                    NaN  EDUCATION SERVICES, Library, Libraries, Public...
# ...

# %%
type(df[['email','keywords']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes  # ye apne aap column kitne h data me , sath hi python ne unn column ko kon sa datatype smgha h ye v btayega
          # object means yha pr string
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments           object
# alternate_name              object
# application_process         object
# audience                    object
# description                 object
# eligibility                 object
# email                       object
# fees                        object
# funding_sources             object
# interpretation_services     object
# keywords                    object
# languages                   object
# name                        object
# required_documents          object
# service_areas               object
# status                      object
# wait_time                   object
# website                     object
# taxonomy_ids                object
# dtype: object

# %%
# ab hme excel sheet ke data ko read karna h ,

df1 = pd.read_excel('LUSID EXCEL - Setting up your market data.xlsx')

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Unnamed: 0    float64
# Unnamed: 1    float64
# Unnamed: 2    float64
# Unnamed: 3     object
# Unnamed: 4     object
# Unnamed: 5     object
# Unnamed: 6    float64
# Unnamed: 7     object
# Unnamed: 8     object
# Unnamed: 9     object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df1[['Unnamed: 6','Unnamed: 7','Unnamed: 8']]
# Out:
#     Unnamed: 6                                         Unnamed: 7  \
# 0          NaN                                                NaN
# 1          NaN                                                NaN
# 2          NaN                                                NaN
# 3          NaN                                                NaN
# 4          NaN                                                NaN
# 5          NaN                                                NaN
# 6          NaN                                                NaN
# 7          NaN                                                NaN
# 8          NaN                                                NaN
# 9          NaN                                                NaN
# 10         NaN                                                NaN
# 11         NaN  LUSID also accepts UTC, UTS offsets and cutlabels
# 12         NaN                                                NaN
# ...

# %%
# kisi link ke data ko read karna h

# %%
pd.read_csv("https://github.com/anu78600/Learning/blob/main/8.Pandas/services.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 pd.read_csv("https://github.com/anu78600/Learning/blob/main/8.Pandas/services.csv")
#
# ...

# %%
# to solve above error we do something :

# %%
df2 = pd.read_csv("https://github.com/anu78600/Learning/blob/main/8.Pandas/services.csv",error_bad_lines=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df2 = pd.read_csv("https://github.com/anu78600/Learning/blob/main/8.Pandas/services.csv",error_bad_lines=False)
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'
